# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
Crime_Statitics=pd.read_csv('SouthAfricaCrimeStats_v2[1].csv')

# %%
Crime_Statitics
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %%
Crime_Statistics_by_province_yearly = Crime_Statitics.groupby('Province')[['2005-2006', '2006-2007', '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016']]

# %%
Crime_Statistics_by_province
# Out:
#                2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  \
# Province
# Eastern Cape      238977     228884     220813     216658     217230
# Free State        137987     128227     127955     132335     127512
# Gauteng           654817     639635     615618     638186     640074
# Kwazulu/Natal     345784     343798     328368     340095     349103
# Limpopo           106983     104857      97166      97565      99610
# Mpumalanga        134829     131444     125954     131410     128814
# North West        118840     112471     112340     117118     115680
# Northern Cape      56515      52689      48954      50277      49746
# Western Cape      381825     396712     395281     398240     417619
#
#                2010-2011  2011-2012  2012-2013  2013-2014  2014-2015  \
# Province
# Eastern Cape      215012     214462     209124     210248     202582
# Free State        121997     126389     131785     126290     118879
# ...

# %%
Crime_Statistics_by_province.T.plot(kind='bar', figsize=(12, 8))

plt.title('Crime Statistics by Province (2005-2016)')
plt.xlabel('Year')
plt.ylabel('Total Crime')

plt.legend(title='Province', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
Total=Crime_Statistics_by_province.sum(axis=1)

# %%
Total.plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('Total Crime Statistics by Province (2005-2016)')
plt.xlabel('Province')
plt.ylabel('Total Crime (2005-2016)')
plt.show(

# %%
PoliceStations=Crime_Statitics.groupby('Province')['Station'].count()

# %%
PoliceStations.plot(kind='bar', figsize=(12, 8))
plt.title('Total number of police stations per province')
plt.xlabel('Province')
plt.ylabel('Total police stations')
plt.show()

# %%
categories=Crime_Statitics.groupby('Category')[['2005-2006', '2006-2007', '2007-2008', '2008-2009', '2009-2010', '2010-2011', '2011-2012', '2012-2013', '2013-2014', '2014-2015', '2015-2016']].sum()

# %%
categories
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                      424690     407714
# Arson                                                    7247       7438
# Assault with the intent to inflict grievous bod...     225659     216754
# Attempted murder                                        20369      19957
# Bank robbery                                               59        130
# Burglary at non-residential premises                    54217      58240
# Burglary at residential premises                       261403     248462
# Carjacking                                              12783      13534
# Commercial crime                                        51911      59637
# Common assault                                         225436     207869
# Common robbery                                          74221      70598
# Driving under the influence of alcohol or drugs         33076      38210
# ...

# %%
Total_categories=categories.sum(axis=1)
Total_categories
# Out:
# Category
# All theft not mentioned elsewhere                          4120351
# Arson                                                        67688
# Assault with the intent to inflict grievous bodily harm    2179207
# Attempted murder                                            193335
# Bank robbery                                                   628
# Burglary at non-residential premises                        751717
# Burglary at residential premises                           2763950
# Carjacking                                                  137621
# Commercial crime                                            807206
# Common assault                                             2043267
# Common robbery                                              647739
# Driving under the influence of alcohol or drugs             660174
# Drug-related crime                                         1879871
# Illegal possession of firearms and ammunition               157902
# ...

# %%
Total_categories.plot(kind='bar', figsize=(12, 8), color='skyblue')

plt.title('Total Crimes per Crime Category (2005-2016)')
plt.xlabel('Crime Category')
plt.ylabel('Total Crimes')


plt.tight_layout()
plt.show()
